# %%
import numpy as np
import pandas as pd


from mff.new_cap import read_base_data
from mff.utils import c_round

# %%
data = read_base_data(2024)

# %%
data[data["area_biss_criss"] <1]

# %%
data.loc[data["area_biss_criss"] > 1, "area_biss_criss"].sum()
